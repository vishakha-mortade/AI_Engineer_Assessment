# %%
pip install langchain-text-splitters
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: C:\Users\visha\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
import pandas as pd

# Initialize the application
app = FastAPI(
    title="Support Ticket AI Assistant",
    description="API for querying and detecting anomalies in customer support tickets.",
    version="1.0.0"
)

# Pydantic models for request validation
class QueryRequest(BaseModel):
    question: str

class QueryResponse(BaseModel):
    answer: str
    confidence_score: float = 1.0

# Load data at startup to keep endpoints fast
try:
    df = pd.read_csv("support_tickets.csv")
except FileNotFoundError:
    df = pd.DataFrame() # Fallback or handle gracefully

@app.get("/health")
async def health_check():
    """Verify system status and data ingestion."""
    if df.empty:
        raise HTTPException(status_code=503, detail="Dataset not loaded.")
    return {"status": "healthy", "records_loaded": len(df)}

@app.post("/api/query", response_model=QueryResponse)
async def ask_question(request: QueryRequest):
    """
    Process natural language questions about the support tickets.
    Routes the query to the local LLM agent.
    """
    if not request.question.strip():
        raise HTTPException(status_code=400, detail="Question cannot be empty.")
    
    # TODO: Initialize LangChain/Ollama agent here
    # Example: answer = agent.run(request.question)
    
    # Placeholder response
    return QueryResponse(answer="LLM integration pending.")
# Out:
# --------------------------------------------------------------------
# ModuleNotFoundError                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from fastapi import FastAPI, HTTPException
#       2 from pydantic import BaseModel
#       3 import pandas as pd
#       4
#
# ModuleNotFoundError: No module named 'fastapi'
